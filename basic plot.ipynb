# %% [markdown]
# <a href="https://colab.research.google.com/github/IanHung0109/Colab-Programming-1/blob/main/basic%20plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]

# %%
plt.plot(x)

# %%
y=[i*i for i in x]

# %%
y
# Out:
# [1, 4, 9, 16]

# %%
plt.plot(y)
